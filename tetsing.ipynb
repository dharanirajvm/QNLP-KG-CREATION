# %%
from infer_relation_triple import initialize_inference, predict_relation, extract_entities, predict_triple
# initialize_inference("runs/lambeq_relation_YYYYMMDD_HHMMSS")
# print(predict_relation("Alice works at Google in London."))
# print(extract_entities("Alice works at Google in London."))
# print(predict_triple("Alice works at Google in London."))

# %%
initialize_inference("runs/lambeq_relation_20260304_193030")

# %%
print(predict_relation("Alice works at Google in London."))
print(extract_entities("Alice works at Google in London."))
print(predict_triple("Alice works at Google in London."))
# Out:
# WARNING:re_inference:Unseen circuit at inference; expanding model circuit map and retrying.
# WARNING:re_inference:Expanded model has 9 missing keys (likely unseen token parameters).
# {'sentence': 'Alice works at Google in London.', 'predicted_relation': 'works_at', 'confidence': 0.8009978532791138, 'probabilities': {'lives_in': 0.18553203344345093, 'works_at': 0.8009978532791138, 'studies_at': 0.0024391082115471363, 'born_in': 4.620796297454045e-23, 'located_in': 1.228225979715879e-14, 'part_of': 1.967085881915409e-05, 'married_to': 8.066987629653556e-15, 'parent_of': 1.9473043177953286e-09, 'owns': 0.005585539620369673, 'uses': 0.005425823852419853}}
# ('Alice', 'Google')
# ('Alice', 'works_at', 'Google')

# %%
# olivia actively trains at yale daily
print(predict_relation("olivia actively trains at yale daily"))
print(extract_entities("olivia actively trains at yale daily"))
print(predict_triple("olivia actively trains at yale daily"))
# Out:
# {'sentence': 'olivia actively trains at yale daily', 'predicted_relation': 'studies_at', 'confidence': 0.8595030307769775, 'probabilities': {'lives_in': 0.0008083293214440346, 'works_at': 0.13963335752487183, 'studies_at': 0.8595030307769775, 'born_in': 3.910348358062974e-20, 'located_in': 8.975153953372228e-12, 'part_of': 2.990799998769944e-07, 'married_to': 1.5784377183081233e-06, 'parent_of': 6.62659260797227e-08, 'owns': 1.6471345176682917e-08, 'uses': 5.3263465815689415e-05}}
# ('olivia', 'daily')
# ('olivia', 'studies_at', 'daily')

# %%
# zane routinely handles docker carefully
print(predict_relation("zane routinely handles docker carefully"))
print(extract_entities("zane routinely handles docker carefully"))  
print(predict_triple("zane routinely handles docker carefully"))
# Out:
# {'sentence': 'zane routinely handles docker carefully', 'predicted_relation': 'uses', 'confidence': 0.9975079298019409, 'probabilities': {'lives_in': 5.164242338651093e-06, 'works_at': 0.0002927016466856003, 'studies_at': 0.00016105938993860036, 'born_in': 2.667468459657818e-12, 'located_in': 6.390258322497289e-10, 'part_of': 0.0009337110677734017, 'married_to': 3.030284898876412e-13, 'parent_of': 4.3655187909052984e-08, 'owns': 0.0010995679767802358, 'uses': 0.9975079298019409}}
# ('zane', 'docker')
# ('zane', 'uses', 'docker')

# %%
#xavier regularly operates tableau effectively
print(predict_relation("xavier regularly operates tableau effectively"))
print(extract_entities("xavier regularly operates tableau effectively"))
print(predict_triple("xavier regularly operates tableau effectively"))
# Out:
# {'sentence': 'xavier regularly operates tableau effectively', 'predicted_relation': 'uses', 'confidence': 0.5596797466278076, 'probabilities': {'lives_in': 0.013216588646173477, 'works_at': 0.3609187602996826, 'studies_at': 0.029804512858390808, 'born_in': 1.0419662528626805e-11, 'located_in': 1.1117276699224021e-06, 'part_of': 0.027142195031046867, 'married_to': 1.8021688674707548e-07, 'parent_of': 0.0002263859787490219, 'owns': 0.009010463953018188, 'uses': 0.5596797466278076}}
# ('xavier', 'tableau')
# ('xavier', 'uses', 'tableau')

# %%
#rachel diligently learns at yale now
print(predict_relation("rachel diligently learns at yale now"))
print(extract_entities("rachel diligently learns at yale now"))
print(predict_triple("rachel diligently learns at yale now"))
# Out:
# {'sentence': 'rachel diligently learns at yale now', 'predicted_relation': 'studies_at', 'confidence': 0.509149432182312, 'probabilities': {'lives_in': 0.06003117933869362, 'works_at': 0.42637673020362854, 'studies_at': 0.509149432182312, 'born_in': 2.9375089944576006e-21, 'located_in': 1.9594204798728705e-14, 'part_of': 2.810050136758946e-05, 'married_to': 1.4942818093999222e-09, 'parent_of': 4.035746678709984e-05, 'owns': 6.930114260228493e-10, 'uses': 0.004374174401164055}}
# ('rachel', 'yale')
# ('rachel', 'studies_at', 'yale')

# %%
#mia actively learns at harvard daily
print(predict_relation("mia actively learns at harvard daily"))
print(extract_entities("mia actively learns at harvard daily"))
print(predict_triple("mia actively learns at harvard daily"))
# Out:
# {'sentence': 'mia actively learns at harvard daily', 'predicted_relation': 'studies_at', 'confidence': 0.8386200070381165, 'probabilities': {'lives_in': 0.0010217709932476282, 'works_at': 0.16026398539543152, 'studies_at': 0.8386200070381165, 'born_in': 1.267966420171783e-19, 'located_in': 1.872557837956368e-11, 'part_of': 6.194319439600804e-07, 'married_to': 1.8716287968345569e-06, 'parent_of': 1.2661531911817292e-07, 'owns': 3.291998496024462e-08, 'uses': 9.155982115771621e-05}}
# ('mia actively', 'harvard daily')
# ('mia actively', 'studies_at', 'harvard daily')
